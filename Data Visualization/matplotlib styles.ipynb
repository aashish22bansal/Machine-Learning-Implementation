# %% [markdown]
# # Initial Data

# %%
import matplotlib.pyplot as plt

x1_values = [2012, 2013, 2014, 2015]
y1_values = [4.3, 2.5, 3.5, 4.5]

x2_values = [2012, 2013, 2014, 2015]
y2_values = [2.4, 4.4, 1.8, 2.8]

x3_values = [2012, 2013, 2014, 2015]
y3_values = [2, 2, 3, 5]

# %% [markdown]
# # Base Line Plot

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure()
plt.plot(x1_values, y1_values, label='Python')
plt.plot(x2_values, y2_values, label='JavaScript')
plt.plot(x3_values, y3_values, label='R')

plt.xlim(2012, 2015)
plt.ylim(0, 6)
plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
plt.yticks([1, 2, 3, 4, 5])

plt.xlabel('')
plt.ylabel('Web Searches')

plt.legend(loc='upper center', ncol=3)
plt.grid(True)

plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# # Adding Distinct Colors to the Lines

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure()
plt.plot(x1_values, y1_values, label='Python', lw=3, color='#1f77b4')
plt.plot(x2_values, y2_values, label='JavaScript', lw=3, color='#ff7f0e')
plt.plot(x3_values, y3_values, label='R', lw=3, color='#2ca02c')

plt.xlim(2012, 2015)
plt.ylim(0, 6)
plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
plt.yticks([1, 2, 3, 4, 5])

plt.xlabel('')
plt.ylabel('Web Searches')

plt.legend(loc='upper center', ncol=3)
plt.grid(True)

plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# # Adding Colors as `rcParams`

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from cycler import cycler

plt.rcParams['axes.prop_cycle'] = cycler(color=['#1f77b4', '#ff7f0e', '#2ca02c'])
plt.rcParams['lines.linewidth'] = 3

plt.figure()
plt.plot(x1_values, y1_values, label='Python')
plt.plot(x2_values, y2_values, label='JavaScript')
plt.plot(x3_values, y3_values, label='R')

plt.xlim(2012, 2015)
plt.ylim(0, 6)
plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
plt.yticks([1, 2, 3, 4, 5])

plt.xlabel('')
plt.ylabel('Web Searches')

plt.legend(loc='upper center', ncol=3)
plt.grid(True)

plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# The error occurs because `axes.color_cycle` is no longer a valid rcParam in recent versions of matplotlib.
#
# To set the color cycle, use `axes.prop_cycle` with a cycler object.
#
# Make sure to import `cycler` and use `axes.prop_cycle` for color cycling.

# %% [markdown]
# Customizing matplotlib rcParams: http://matplotlib.org/users/customizing.html#dynamic-rc-settings

# %% [markdown]
# # Available `matplotlib` Styling

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Adding Style using `Context()` Function

# %% [markdown]
# ## Style: `fivethirtyeight`

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# ## Comparing `fivethirtyeight` and `bmh` Styles

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# Create the first visualization
with plt.style.context('bmh'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# Create a second visualization
with plt.style.context('fivethirtyeight'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# # Obtaining `matplotlib` Configured Location

# %%
import matplotlib as mpl
mpl.get_configdir()
# Out:
# 'C:\\Users\\aashi\\.matplotlib'

# %% [markdown]
# ## Validating the `matplotlib` Configured Location

# %%
#!ls /Users/randal_olson/.matplotlib/stylelib/
# !dir %USERPROFILE%\.matplotlib\stylelib
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 6073-CA90
#
#  Directory of C:\Users\aashi\.matplotlib\stylelib
#
# 27-07-2025  21:45    <DIR>          .
# 27-07-2025  21:45    <DIR>          ..
#                0 File(s)              0 bytes
#                2 Dir(s)  443,334,434,816 bytes free

# %% [markdown]
# ## Creating required Directory (if it does not exist)

# %% [markdown]
# If `.matplotlib\stylelib` is not found, you need to create the directory before saving custom style files.
# You can do this in a Jupyter notebook cell:

# %%
import os

stylelib_dir = os.path.join(os.path.expanduser("~"), ".matplotlib", "stylelib")
os.makedirs(stylelib_dir, exist_ok=True)
print("Created:", stylelib_dir)
# Out:
# Created: C:\Users\aashi\.matplotlib\stylelib

# %% [markdown]
# This will ensure the `stylelib` folder exists in your user profile. Now you can save custom style files there.

# %% [markdown]
# ## Custom `matplotlib` Styling

# %%
# Original Style

custom_style = '''
figure.figsize: 12, 7
figure.edgecolor: white
figure.facecolor: white

lines.linewidth: 2.5
lines.markeredgewidth: 0
lines.markersize: 10
lines.dash_capstyle: butt

legend.fancybox: True

font.size: 14

axes.prop_cycle: cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
axes.linewidth: 0
axes.titlesize: 22
axes.labelsize: 16

xtick.labelsize: 14
ytick.labelsize: 14
xtick.major.size: 0
xtick.minor.size: 0
ytick.major.size: 0
ytick.minor.size: 0

axes.grid: True
grid.alpha: 0.3
grid.linewidth: 0.5
grid.linestyle: --
grid.color: black

savefig.transparent: False
savefig.bbox: tight
savefig.format: png
'''

mpl_style_location = ('{}/stylelib/my_custom_style.mplstyle'.format(mpl.get_configdir()))

with open(mpl_style_location, 'w') as out_file:
    out_file.write(custom_style)

# %%
custom_style = '''
figure.figsize: 12, 7
figure.edgecolor: white
figure.facecolor: white

lines.linewidth: 2.5
lines.markeredgewidth: 0
lines.markersize: 10
lines.dash_capstyle: butt

legend.fancybox: True

font.size: 14

axes.prop_cycle: cycler("color", ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
axes.linewidth: 0
axes.titlesize: 22
axes.labelsize: 16

xtick.labelsize: 14
ytick.labelsize: 14
xtick.major.size: 0
xtick.minor.size: 0
ytick.major.size: 0
ytick.minor.size: 0

axes.grid: True
grid.alpha: 0.3
grid.linewidth: 0.5
grid.linestyle: --
grid.color: black

savefig.transparent: False
savefig.bbox: tight
savefig.format: png
'''

mpl_style_location = ('{}/stylelib/my_custom_style.mplstyle'.format(mpl.get_configdir()))

with open(mpl_style_location, 'w') as out_file:
    out_file.write(custom_style)

# %% [markdown]
# The error is because `axes.color_cycle` is not a valid rcParam in recent matplotlib versions.
# You should replace it with `axes.prop_cycle` and use the `cycler` syntax.
#
# **How to fix your custom style file:**
#
# Replace this line:
#
# `axes.color_cycle: 1f77b4, ff7f0e, 2ca02c, d62728, 9467bd, 8c564b, e377c2, 7f7f7f, bcbd22, 17becf`
#
# with:
#
# `axes.prop_cycle: cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])`
#
# **Example snippet for your `.mplstyle` file:**
#
# ```Python
# \.matplotlib\stylelib\my_custom_style.mplstyle
# axes.prop_cycle: cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
# ```
#
# This will resolve the bad key error and apply your color cycle correctly.
#
# Similar code found with 1 license type

# %% [markdown]
# Look up more rcParams at http://matplotlib.org/users/customizing.html#dynamic-rc-settings

# %% [markdown]
# # Available Styles

# %%
plt.style.reload_library()
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'my_custom_style',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %% [markdown]
# # Loading Custom Style

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

with plt.style.context('my_custom_style'):
    plt.figure()
    plt.plot(x1_values, y1_values, label='Python')
    plt.plot(x2_values, y2_values, label='JavaScript')
    plt.plot(x3_values, y3_values, label='R')

    plt.xlim(2012, 2015)
    plt.ylim(0, 6)
    plt.xticks([2012, 2013, 2014, 2015], ['2012', '2013', '2014', '2015'])
    plt.yticks([1, 2, 3, 4, 5])

    plt.xlabel('')
    plt.ylabel('Web Searches')

    plt.legend(loc='upper center', ncol=3)
    plt.grid(True)

    plt.savefig('web-searches.png', dpi=150)

# %% [markdown]
# # Tips for matplotlib styles
#
# ### Always use styles!
#
# Saves time, saves code
#
# ### Use `plt.style.context()`
#
# You *can* use `plt.style.use()`, but not ideal
#
# ### Create separate styles for colors and figure formatting
#
# Might need to switch between grayscale and color
#
# ```python
#     with plt.style.context(['figure_formatting', 'colorbrewer_colors']):
# ```
#
# to
#
# ```python
#     with plt.style.context(['figure_formatting', 'grayscale_colors']):
# ```
