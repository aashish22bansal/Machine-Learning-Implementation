# %% [markdown]
# # Importing Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Histograms
#
# **Purpose**: Showing the spread of a data column.
#
# **matplotlib function**: [`hist(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.hist)
#
# * `x`: List of values to display the distribution of.

# %%
column_data = np.random.normal(42, 3, 1000)

plt.figure()

plt.hist(column_data)
# Out:
# (array([  4.,  21.,  64., 138., 240., 247., 169.,  80.,  32.,   5.]),
#  array([32.2661534 , 34.19570791, 36.12526241, 38.05481692, 39.98437142,
#         41.91392593, 43.84348043, 45.77303493, 47.70258944, 49.63214394,
#         51.56169845]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# **Commonly used parameters**:
#
# * `color`: Set the color of the bars in the histogram.
#
# * `bins`: Set the number of bins to display in the histogram, or specify specific bins.
#
# * `normed`: Indicate whether the bins should display fractions instead of counts.

# %%
column_data = np.random.normal(42, 3, 1000)

plt.figure()

plt.hist(
    column_data,
    color='red',
    bins=50,
    density=True # normed=True is deprecated, use density=True instead
)
# Out:
# (array([0.00274572, 0.        , 0.        , 0.00274572, 0.00274572,
#         0.00823716, 0.01098288, 0.00549144, 0.01647432, 0.0137286 ,
#         0.02471147, 0.03020291, 0.02471147, 0.02745719, 0.03569435,
#         0.05216867, 0.06864299, 0.0851173 , 0.07688014, 0.10159162,
#         0.09335446, 0.09060874, 0.10982878, 0.13728597, 0.10159162,
#         0.10433734, 0.12355737, 0.10708306, 0.12355737, 0.10982878,
#         0.12904881, 0.14277741, 0.0988459 , 0.10982878, 0.09060874,
#         0.09610018, 0.06864299, 0.05491439, 0.04942295, 0.03020291,
#         0.04393151, 0.03844007, 0.03294863, 0.02471147, 0.01098288,
#         0.00823716, 0.00274572, 0.01098288, 0.00274572, 0.00823716]),
#  array([32.14512988, 32.50933315, 32.87353642, 33.23773969, 33.60194297,
#         33.96614624, 34.33034951, 34.69455278, 35.05875606, 35.42295933,
#         35.7871626 , 36.15136587, 36.51556915, 36.87977242, 37.24397569,
#         37.60817896, 37.97238224, 38.33658551, 38.70078878, 39.06499205,
#         39.42919533, 39.7933986 , 40.15760187, 40.52180514, 40.88600842,
#         41.25021169, 41.61441496, 41.97861823, 42.34282151, 42.70702478,
#         43.07122805, 43.43543132, 43.7996346 , 44.16383787, 44.52804114,
#         44.89224441, 45.25644769, 45.62065096, 45.98485423, 46.3490575 ,
#         46.71326078, 47.07746405, 47.44166732, 47.80587059, 48.17007387,
#         48.53427714, 48.89848041, 49.26268368, 49.62688696, 49.99109023,
#         50.3552935 ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# The `normed` parameter in `plt.hist()` is deprecated and replaced by `density` in recent versions of matplotlib.
# Replace `normed=True` with `density=True` to fix the error.
#
# Here’s the corrected code:

# %%
column_data = np.random.normal(42, 3, 1000)

plt.figure()

plt.hist(
    column_data,
    color='red',
    bins=50,
    density=True
)
# Out:
# (array([0.0052898 , 0.0026449 , 0.0026449 , 0.0026449 , 0.00793469,
#         0.0026449 , 0.0052898 , 0.00793469, 0.02115919, 0.01586939,
#         0.01851429, 0.03967347, 0.04231837, 0.03967347, 0.07405715,
#         0.10050613, 0.08199184, 0.10579593, 0.11108572, 0.07934694,
#         0.12960001, 0.12166531, 0.15604899, 0.1401796 , 0.12166531,
#         0.1348898 , 0.1348898 , 0.11902042, 0.10844082, 0.09786123,
#         0.09521633, 0.08728164, 0.07670205, 0.07141225, 0.06347756,
#         0.06083266, 0.02644898, 0.01851429, 0.03702857, 0.01586939,
#         0.0052898 , 0.02909388, 0.0026449 , 0.0026449 , 0.0026449 ,
#         0.01586939, 0.        , 0.        , 0.        , 0.0026449 ]),
#  array([32.80680847, 33.18489486, 33.56298126, 33.94106765, 34.31915404,
#         34.69724044, 35.07532683, 35.45341323, 35.83149962, 36.20958602,
#         36.58767241, 36.96575881, 37.3438452 , 37.7219316 , 38.10001799,
#         38.47810439, 38.85619078, 39.23427718, 39.61236357, 39.99044997,
#         40.36853636, 40.74662276, 41.12470915, 41.50279554, 41.88088194,
#         42.25896833, 42.63705473, 43.01514112, 43.39322752, 43.77131391,
#         44.14940031, 44.5274867 , 44.9055731 , 45.28365949, 45.66174589,
#         46.03983228, 46.41791868, 46.79600507, 47.17409147, 47.55217786,
#         47.93026426, 48.30835065, 48.68643704, 49.06452344, 49.44260983,
#         49.82069623, 50.19878262, 50.57686902, 50.95495541, 51.33304181,
#         51.7111282 ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# This will plot a normalized histogram.

# %% [markdown]
# # Box plots
#
# **Purpose**: Summarize the distribution of a data column.
#
# **matplotlib function**: [`boxplot(x)`](http://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.boxplot)
#
# * `x`: List of values (or list of lists of values) to display the distribution of.

# %%
two_columns_data = [
    np.random.normal(57, 3, 1000),
    np.random.normal(42, 7, 1000)
]

plt.boxplot(two_columns_data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1150e452c10>,
#   <matplotlib.lines.Line2D at 0x1150e452d50>,
#   <matplotlib.lines.Line2D at 0x1150e4534d0>,
#   <matplotlib.lines.Line2D at 0x1150e453610>],
#  'caps': [<matplotlib.lines.Line2D at 0x1150e452e90>,
#   <matplotlib.lines.Line2D at 0x1150e452fd0>,
#   <matplotlib.lines.Line2D at 0x1150e453750>,
#   <matplotlib.lines.Line2D at 0x1150e453890>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1150e452ad0>,
#   <matplotlib.lines.Line2D at 0x1150e453390>],
#  'medians': [<matplotlib.lines.Line2D at 0x1150e453110>,
#   <matplotlib.lines.Line2D at 0x1150e4539d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1150e453250>,
#   <matplotlib.lines.Line2D at 0x1150e453b10>],
#  'means': []}

# %% [markdown]
# **Commonly used parameters**:
#
# * `labels`: Set the labels for the box plots.
#
# * `notch`: Indicate whether notches should be created around the median.
#
# * `bootstrap`: Indicate whether the notches around the median should be bootstrapped.

# %%
two_columns_data = [
    np.random.normal(57, 3, 1000),
    np.random.normal(42, 7, 1000)
]

plt.boxplot(
    two_columns_data,
    tick_labels=['A', 'B'], # To resolve the deprecation warning, replace the `labels` parameter with `tick_labels` in your `plt.boxplot()` call.
    notch=True,
    bootstrap=10000
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1150e78a210>,
#   <matplotlib.lines.Line2D at 0x1150e78a350>,
#   <matplotlib.lines.Line2D at 0x1150e78aad0>,
#   <matplotlib.lines.Line2D at 0x1150e78ac10>],
#  'caps': [<matplotlib.lines.Line2D at 0x1150e78a490>,
#   <matplotlib.lines.Line2D at 0x1150e78a5d0>,
#   <matplotlib.lines.Line2D at 0x1150e78ad50>,
#   <matplotlib.lines.Line2D at 0x1150e78ae90>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1150e78a0d0>,
#   <matplotlib.lines.Line2D at 0x1150e78a990>],
#  'medians': [<matplotlib.lines.Line2D at 0x1150e78a710>,
#   <matplotlib.lines.Line2D at 0x1150e78afd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1150e78a850>,
#   <matplotlib.lines.Line2D at 0x1150e78b110>],
#  'means': []}
