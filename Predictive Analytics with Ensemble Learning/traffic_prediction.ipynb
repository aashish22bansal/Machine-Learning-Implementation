# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, mean_absolute_error
from sklearn import model_selection, preprocessing
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# # Load input data

# %%
input_file = 'traffic_data.txt'
data = []
with open(input_file, 'r') as f:
    for line in f.readlines():
        items = line[:-1].split(',')
        data.append(items)

# %%
data = np.array(data)

# %% [markdown]
# # Convert string data to numerical data

# %%
label_encoder = [] 
X_encoded = np.empty(data.shape)
for i, item in enumerate(data[0]):
    if item.isdigit():
        X_encoded[:, i] = data[:, i]
    else:
        label_encoder.append(preprocessing.LabelEncoder())
        X_encoded[:, i] = label_encoder[-1].fit_transform(data[:, i])

# %%
X = X_encoded[:, :-1].astype(int)
y = X_encoded[:, -1].astype(int)

# %% [markdown]
# # Split data into training and testing datasets

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, y, test_size=0.25, random_state=5
)

# %% [markdown]
# # Extremely Random Forests regressor

# %%
params = {'n_estimators': 100, 'max_depth': 4, 'random_state': 0}
regressor = ExtraTreesRegressor(**params)
regressor.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(max_depth=4, random_state=0)

# %% [markdown]
# # Compute the regressor performance on test data

# %%
y_pred = regressor.predict(X_test)
print("Mean absolute error:", round(mean_absolute_error(y_test, y_pred), 2))
# Out:
# Mean absolute error: 7.42

# %% [markdown]
# # Testing encoding on single data instance

# %%
test_datapoint = ['Saturday', '10:20', 'Atlanta', 'no']
test_datapoint_encoded = [-1] * len(test_datapoint)
count = 0

# %%
test_datapoint
# Out:
# ['Saturday', '10:20', 'Atlanta', 'no']

# %%
test_datapoint_encoded
# Out:
# [-1, -1, -1, -1]

# %%
label_encoder
# Out:
# [LabelEncoder(), LabelEncoder(), LabelEncoder(), LabelEncoder()]

# %%
test_datapoint = np.array(test_datapoint).reshape((-1,1))

# %%
label_encoder[1].transform(test_datapoint[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\aashi\GitHub\9781786464392\venv\Lib\site-packages\sklearn\utils\_encode.py:235, in _encode(values, uniques, check_unknown)
#     234 try:
# --> 235     return _map_to_integer(values, uniques)
#     236 except KeyError as e:
#
# File c:\Users\aashi\GitHub\9781786464392\venv\Lib\site-packages\sklearn\utils\_encode.py:174, in _map_to_integer(values, uniques)
#     173 table = _nandict({val: i for i, val in enumerate(uniques)})
# --> 174 return xp.asarray([table[v] for v in values], device=device(values))
#
# File c:\Users\aashi\GitHub\9781786464392\venv\Lib\site-packages\sklearn\utils\_encode.py:167, in _nandict.__missing__(self, key)
#     166     return self.nan_value
# --> 167 raise KeyError(key)
#
# KeyError: np.str_('Saturday')
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 label_encoder[1].transform(test_datapoint[0])
#
# File c:\Users\aashi\GitHub\9781786464392\venv\Lib\site-packages\sklearn\preprocessing\_label.py:134, in LabelEncoder.transform(self, y)
#     131 if _num_samples(y) == 0:
#     132     return xp.asarray([])
# --> 134 return _encode(y, uniques=self.classes_)
#
# File c:\Users\aashi\GitHub\9781786464392\venv\Lib\site-packages\sklearn\utils\_encode.py:237, in _encode(values, uniques, check_unknown)
#     235         return _map_to_integer(values, uniques)
#     236     except KeyError as e:
# --> 237         raise ValueError(f"y contains previously unseen labels: {e}")
#     238 else:
#     239     if check_unknown:
#
# ValueError: y contains previously unseen labels: np.str_('Saturday')

# %%
for i, item in enumerate(test_datapoint):
    if str(item).isdigit():
        test_datapoint_encoded[i] = int(test_datapoint[i])
    else:
        test_datapoint_encoded[i] = int(label_encoder[count].transform(test_datapoint[i]))
        count = count + 1
# Out:
# C:\Users\aashi\AppData\Local\Temp\ipykernel_35048\2593853669.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   test_datapoint_encoded[i] = int(label_encoder[count].transform(test_datapoint[i]))
# C:\Users\aashi\AppData\Local\Temp\ipykernel_35048\2593853669.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   test_datapoint_encoded[i] = int(label_encoder[count].transform(test_datapoint[i]))
# C:\Users\aashi\AppData\Local\Temp\ipykernel_35048\2593853669.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   test_datapoint_encoded[i] = int(label_encoder[count].transform(test_datapoint[i]))
# C:\Users\aashi\AppData\Local\Temp\ipykernel_35048\2593853669.py:5: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   test_datapoint_encoded[i] = int(label_encoder[count].transform(test_datapoint[i]))

# %%
test_datapoint_encoded = np.array(test_datapoint_encoded)

# %% [markdown]
# # Predict the output for the test datapoint

# %%
print("Predicted traffic:", int(regressor.predict([test_datapoint_encoded])[0]))
# Out:
# Predicted traffic: 26
